# %%
import numpy as np

# %%
#Membuat vector kolom [4:1] yang berisi 4 baris 1 kolom
v = np.array([[25],
      [2],
      [-3],
      [-23]])
v
# Out:
# array([[ 25],
#        [  2],
#        [ -3],
#        [-23]])

# %%
#Ukuran dimensi dari vector
v.shape
# Out:
# (4, 1)

# %%
#Melakukan Transpose pada vector kolom
v_transpose = v.T
v_transpose
# Out:
# array([[ 25,   2,  -3, -23]])

# %%
#Ukuran dimensi vector setelah di transpose
v_transpose.shape
# Out:
# (1, 4)
